# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"E:\Datasets\Customer-Churn-Records.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %%
(df.Exited.value_counts()[1]/df.Exited.count())*100
# Out:
# 20.380000000000003

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.Exited.value_counts()[1]
# Out:
# 2038

# %%
vc=df[df.Exited==1].CustomerId.count()

# %%
vc
# Out:
# 2038

# %%
df.Age.min()
# Out:
# 18

# %%
df.Age.max()
# Out:
# 92

# %%
df.Geography.nunique()
# Out:
# 3

# %%
df.CreditScore.mean()
# Out:
# 650.5288

# %%
df[df.Balance>=10000].CustomerId.count()
# Out:
# 6382

# %%
df[df.Exited==1].EstimatedSalary.mean()
# Out:
# 101509.90878312073

# %%
df[(df.Exited==0) & (df.HasCrCard==1)].CustomerId.count()
# Out:
# 5630

# %%
df["Card Type"].value_counts()
# Out:
# DIAMOND     2507
# GOLD        2502
# SILVER      2496
# PLATINUM    2495
# Name: Card Type, dtype: int64

# %%
df[df["Exited"]==0]["Satisfaction Score"].mean()
# Out:
# 3.017960311479528

# %%
#Calculate the mean satisfaction score for customers who exited and those who didn't. 
df.groupby("Exited")["Satisfaction Score"].mean()
# Out:
# Exited
# 0    3.017960
# 1    2.997547
# Name: Satisfaction Score, dtype: float64

# %%
#Calculate the average balance for each unique geography ("Geography") and gender combination.
df.groupby(["Geography","Gender"])["Balance"].mean()
# Out:
# Geography  Gender
# France     Female     60322.670159
#            Male       63546.284875
# Germany    Female    119145.966471
#            Male      120259.668222
# Spain      Female     59862.092534
#            Male       63352.833746
# Name: Balance, dtype: float64

# %%
#Calculate the percentage of customers who complained ("Complain") for each card type.
complain_pre=df.groupby("Card Type").Complain.mean()*100
complain_pre
# Out:
# Card Type
# DIAMOND     21.818907
# GOLD        19.344524
# PLATINUM    20.480962
# SILVER      20.112179
# Name: Complain, dtype: float64

# %%
df2=pd.DataFrame()
df2["Total customers"]=df.groupby(["Card Type"]).CustomerId.count()
df2["complained"]=df[df.Complain==1].groupby("Card Type").CustomerId.count()
df2["complain%"]= df2.complained/df2["Total customers"]*100
df2
# Out:
#            Total customers  complained  complain%
# Card Type
# DIAMOND               2507         547  21.818907
# GOLD                  2502         484  19.344524
# PLATINUM              2495         511  20.480962
# SILVER                2496         502  20.112179

# %%
#Find the mean "Point Earned" for active members and inactive members.
df.groupby("IsActiveMember")["Point Earned"].mean()
# Out:
# IsActiveMember
# 0    607.675397
# 1    605.422831
# Name: Point Earned, dtype: float64

# %%
#Select rows where "Age" is between 30 and 40, and the "CreditScore" is greater than 700.
df[(df.Age>30) & (df.Age<40) & (df.CreditScore>700)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 24           25    15625047          Yen          846    France  Female   38
# 26           27    15736816        Young          756   Germany    Male   36
# 37           38    15729599      Lorenzo          804     Spain    Male   33
# 38           39    15717426    Armstrong          850    France    Male   36
# 45           46    15754849        Tyler          776   Germany  Female   32
# ...         ...         ...          ...          ...       ...     ...  ...
# 9980       9981    15719276         T'ao          741     Spain    Male   35
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# 9997       9998    15584532          Liu          709    France  Female   36
#
# ...

# %%
#Display the rows for customers who have exited ("Exited" = 1) and have a "Balance" greater than $5,000.
df[(df.Exited==1)&(df.Balance>5000)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 2             3    15619304         Onio          502    France  Female   42
# 5             6    15574012          Chu          645     Spain    Male   44
# 7             8    15656148       Obinna          376   Germany  Female   29
# 16           17    15737452        Romeo          653   Germany    Male   58
# 35           36    15794171     Lombardo          475    France  Female   45
# ...         ...         ...          ...          ...       ...     ...  ...
# 9978       9979    15703563        P'eng          774    France    Male   40
# 9981       9982    15672754     Burbidge          498   Germany    Male   42
# 9982       9983    15768163      Griffin          655   Germany  Female   46
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
#
# ...

# %%
#Show the rows for customers with a satisfaction score of 4 or 5.
df[(df["Satisfaction Score"]==4) ^ (df["Satisfaction Score"]==5)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3             4    15701354         Boni          699    France  Female   39
# 4             5    15737888     Mitchell          850     Spain  Female   43
# 5             6    15574012          Chu          645     Spain    Male   44
# 15           16    15643966      Goforth          616   Germany    Male   45
# 19           20    15568982          Hao          726    France  Female   24
# ...         ...         ...          ...          ...       ...     ...  ...
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
# 9996       9997    15569892    Johnstone          516    France    Male   35
#
# ...

# %%
#Create a new column "AgeGroup" based on age, categorizing customers as "Young", "Adult", and "Senior".
df["AgeGroup"]=pd.cut(df.Age,bins =[17,40,60,100],labels=["young","adult","Senior"])
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
def cat(row):
    if row['Age']<=18 :
         category ="Young"
    elif row['Age'] <=40:
         category= "Adult"
    else:
         category= "Senior"
    return category
df['AgeGroup'] = df.apply(cat , axis=1)

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df["AgGroup1"]=df.Age.apply(lambda x : "Young" if x<40 else "Adult" if x<60 else "Senior")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#Calculate the ratio of "Balance" to "EstimatedSalary" for each customer.
df["Bal_Est_ratio"]= df.Balance/df.EstimatedSalary
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
#Sort the DataFrame by "CreditScore" in descending order.
df.sort_values(by=["CreditScore"],ascending=False)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 792         793    15707473     Summers          850   Germany  Female   48
# 4083       4084    15672640  Kambinachi          850     Spain  Female   45
# 4158       4159    15771580     Davison          850    France  Female   38
# 4157       4158    15719793      Watson          850     Spain    Male   62
# 7413       7414    15604536      Vachon          850   Germany  Female   31
# ...         ...         ...         ...          ...       ...     ...  ...
# 8762       8763    15765173         Lin          350    France  Female   60
# 1631       1632    15685372    Azubuike          350     Spain    Male   54
# 9624       9625    15668309      Maslow          350    France  Female   40
# 1838       1839    15758813    Campbell          350   Germany    Male   39
# 8723       8724    15803202   Onyekachi          350    France    Male   51
#
# ...

# %%
#Add a new column "BalanceStatus" with values "High" for balances above $10,000 and "Low" otherwise.
df["BalanceStatus"]=df.Balance.apply(lambda x: "Low" if x<10000 else "High")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...
