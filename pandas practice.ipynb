# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
d=[121,2323,23,24,32,221]
i=['a','b','c','d','e','f']

# %%
pd.Series(d,i)
# Out:
# a     121
# b    2323
# c      23
# d      24
# e      32
# f     221
# dtype: int64

# %%
pd.Series(d)
# Out:
# 0     121
# 1    2323
# 2      23
# 3      24
# 4      32
# 5     221
# dtype: int64

# %%
pd.Series(d,index=['a','b','c','d','e','f'])
# Out:
# a     121
# b    2323
# c      23
# d      24
# e      32
# f     221
# dtype: int64

# %%
pd.DataFrame(d,index=['a','b','c','d','e','f'])
# Out:
#       0
# a   121
# b  2323
# c    23
# d    24
# e    32
# f   221

# %%
df=pd.read_csv('nkm.csv')

# %%
df
# Out:
#                             model_name  model_year       kms_driven  \
# 0        Bajaj Avenger Cruise 220 2017        2017         17000 Km
# 1     Royal Enfield Classic 350cc 2016        2016         50000 Km
# 2                  Hyosung GT250R 2012        2012         14795 Km
# 3           Bajaj Dominar 400 ABS 2017        2017   Mileage 28 Kms
# 4                Jawa Perak 330cc 2020        2020          2000 Km
# ...                                ...         ...              ...
# 7852         Yamaha YZF-R15 150cc 2011        2011          7000 Km
# 7853         Bajaj Discover 100cc 2015        2015  Mileage 80 Kmpl
# 7854           Bajaj Pulsar 180cc 2016        2016          6407 Km
# 7855              Bajaj V15 150cc 2016        2016          7524 Km
# 7856           Bajaj Pulsar 220cc 2016        2016         15000 Km
#
#             owner     location       mileage      power   price
# 0     first owner    hyderabad  \n\n 35 kmpl     19 bhp   63500
# ...

# %%
df.shape
# Out:
# (7857, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7857, step=1)

# %%
df.columns
# Out:
# Index(['model_name', 'model_year', 'kms_driven', 'owner', 'location',
#        'mileage', 'power', 'price'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                             model_name  model_year       kms_driven  \
# 0        Bajaj Avenger Cruise 220 2017        2017         17000 Km
# 1     Royal Enfield Classic 350cc 2016        2016         50000 Km
# 2                  Hyosung GT250R 2012        2012         14795 Km
# 3           Bajaj Dominar 400 ABS 2017        2017   Mileage 28 Kms
# 4                Jawa Perak 330cc 2020        2020          2000 Km
# ...                                ...         ...              ...
# 7852         Yamaha YZF-R15 150cc 2011        2011          7000 Km
# 7853         Bajaj Discover 100cc 2015        2015  Mileage 80 Kmpl
# 7854           Bajaj Pulsar 180cc 2016        2016          6407 Km
# 7855              Bajaj V15 150cc 2016        2016          7524 Km
# 7856           Bajaj Pulsar 220cc 2016        2016         15000 Km
#
#             owner     location       mileage      power   price
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                             model_name  model_year       kms_driven  \
# 0        Bajaj Avenger Cruise 220 2017        2017         17000 Km
# 1     Royal Enfield Classic 350cc 2016        2016         50000 Km
# 2                  Hyosung GT250R 2012        2012         14795 Km
# 3           Bajaj Dominar 400 ABS 2017        2017   Mileage 28 Kms
# 4                Jawa Perak 330cc 2020        2020          2000 Km
# ...                                ...         ...              ...
# 7852         Yamaha YZF-R15 150cc 2011        2011          7000 Km
# 7853         Bajaj Discover 100cc 2015        2015  Mileage 80 Kmpl
# 7854           Bajaj Pulsar 180cc 2016        2016          6407 Km
# 7855              Bajaj V15 150cc 2016        2016          7524 Km
# 7856           Bajaj Pulsar 220cc 2016        2016         15000 Km
#
#             owner     location       mileage      power   price
# ...

# %%
df.head(2)
# Out:
#                          model_name  model_year kms_driven        owner  \
# 0     Bajaj Avenger Cruise 220 2017        2017   17000 Km  first owner
# 1  Royal Enfield Classic 350cc 2016        2016   50000 Km  first owner
#
#     location       mileage      power   price
# 0  hyderabad  \n\n 35 kmpl     19 bhp   63500
# 1  hyderabad  \n\n 35 kmpl  19.80 bhp  115000

# %%
df.head(50)
# Out:
#                                          model_name  model_year  \
# 0                     Bajaj Avenger Cruise 220 2017        2017
# 1                  Royal Enfield Classic 350cc 2016        2016
# 2                               Hyosung GT250R 2012        2012
# 3                        Bajaj Dominar 400 ABS 2017        2017
# 4                             Jawa Perak 330cc 2020        2020
# 5                               KTM Duke 200cc 2012        2012
# 6                           Bajaj Pulsar 180cc 2016        2016
# 7   TVS Apache RTR 200 4V Dual Channel ABS BS6 2020        2020
# 8                               KTM Duke 390cc 2018        2018
# 9                            Yamaha FZ16 150cc 2014        2014
# 10                 Royal Enfield Classic 350cc 2018        2018
# 11               Royal Enfield Himalayan 410cc 2016        2016
# 12          Royal Enfield Bullet Electra 350cc 2017        2017
# 13                        Honda CB Shine 125cc 2018        2018
# ...

# %%
df.tail(10)
# Out:
#                                              model_name  model_year  \
# 7847                   Royal Enfield Classic 350cc 2016        2016
# 7848                           Hero Splendor 100cc 2001        2001
# 7849                        Hero Karizma ZMR 223cc 2011        2011
# 7850  TVS Apache RTR 160 4V Carburetor With Rear Dis...        2018
# 7851                        Bajaj Pulsar RS200 ABS 2015        2015
# 7852                          Yamaha YZF-R15 150cc 2011        2011
# 7853                          Bajaj Discover 100cc 2015        2015
# 7854                            Bajaj Pulsar 180cc 2016        2016
# 7855                               Bajaj V15 150cc 2016        2016
# 7856                            Bajaj Pulsar 220cc 2016        2016
#
#            kms_driven        owner     location       mileage      power  \
# 7847         23000 Km  first owner        delhi  \n\n 35 kmpl  19.80 bhp
# ...

# %%
df.count()
# Out:
# model_name    7857
# model_year    7857
# kms_driven    7857
# owner         7857
# location      7838
# mileage       7846
# power         7826
# price         7857
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# C:\Users\Nkmanithia\AppData\Local\Temp\ipykernel_292\1459321664.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum(axis=1)
# 0        65517
# 1       117016
# 2       302012
# 3       102017
# 4       199520
#          ...
# 7852     57011
# 7853     30015
# 7854     63756
# 7855     51016
# 7856     67016
# Length: 7857, dtype: int64

# %%
df.min()
# Out:
# C:\Users\Nkmanithia\AppData\Local\Temp\ipykernel_292\3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# model_name     Bajaj CT100 B 2016                           ...
# model_year                                                 1950
# kms_driven                                                 0 Km
# owner                                               first owner
# price                                                         0
# dtype: object

# %%
df.max()
# Out:
# C:\Users\Nkmanithia\AppData\Local\Temp\ipykernel_292\1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# model_name    yamaha Libero 110cc 2006
# model_year                        2021
# kms_driven                      Yes Km
# owner                      third owner
# price                          3000000
# dtype: object

# %%
df.max()['price']
# Out:
# C:\Users\Nkmanithia\AppData\Local\Temp\ipykernel_292\4190625019.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()['price']
# 3000000

# %%
df.price.max()
# Out:
# 3000000

# %%
df.model_year.max()           #df.id.max()
# Out:
# 2021

# %%
new=df.sort_values('price',ascending=False)

# %%
b=new.head(10)

# %%
a=new.tail(10)

# %%
pd.concat([a,b],axis=0)
# Out:
#                                   model_name  model_year       kms_driven  \
# 6780                     Hyosung GT250R 2013        2013          5000 Km
# 7697               Yamaha YZF-R15 150cc 2011        2011         21200 Km
# 7649                Hero Karizma 223 cc 2008        2008         22000 Km
# 6795        Royal Enfield Classic 500cc 2014        2014         10200 Km
# 6200            Hero Passion Xpro 110cc 2015        2015          9000 Km
# 7802               TVS Apache RTR 160cc 2011        2011  Mileage 60 Kmpl
# 7810                Hero Splendor 100cc 1996        1996         30000 Km
# 7811                Hero Passion 100cc  2005        2005         35000 Km
# 4786                Bajaj  Pulsar 180cc 2009        2009         60000 Km
# 7667               Bajaj Discover 125ST 2013        2013         13299 Km
# 2133                       Honda CB300R 2021        2021           500 Km
# 4757        Indian Chief Classic 1800cc 2015        2015  Mileage 14 Kmpl
# ...

# %%
a.append(b)
# Out:
# C:\Users\Nkmanithia\AppData\Local\Temp\ipykernel_292\2735396570.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a.append(b)
#                                   model_name  model_year       kms_driven  \
# 6780                     Hyosung GT250R 2013        2013          5000 Km
# 7697               Yamaha YZF-R15 150cc 2011        2011         21200 Km
# 7649                Hero Karizma 223 cc 2008        2008         22000 Km
# 6795        Royal Enfield Classic 500cc 2014        2014         10200 Km
# 6200            Hero Passion Xpro 110cc 2015        2015          9000 Km
# 7802               TVS Apache RTR 160cc 2011        2011  Mileage 60 Kmpl
# 7810                Hero Splendor 100cc 1996        1996         30000 Km
# 7811                Hero Passion 100cc  2005        2005         35000 Km
# 4786                Bajaj  Pulsar 180cc 2009        2009         60000 Km
# ...

# %%
a,b
# Out:
# (                            model_name  model_year       kms_driven  \
#  6780               Hyosung GT250R 2013        2013          5000 Km
#  7697         Yamaha YZF-R15 150cc 2011        2011         21200 Km
#  7649          Hero Karizma 223 cc 2008        2008         22000 Km
#  6795  Royal Enfield Classic 500cc 2014        2014         10200 Km
#  6200      Hero Passion Xpro 110cc 2015        2015          9000 Km
#  7802         TVS Apache RTR 160cc 2011        2011  Mileage 60 Kmpl
#  7810          Hero Splendor 100cc 1996        1996         30000 Km
#  7811          Hero Passion 100cc  2005        2005         35000 Km
#  4786          Bajaj  Pulsar 180cc 2009        2009         60000 Km
#  7667         Bajaj Discover 125ST 2013        2013         13299 Km
#
#               owner   location       mileage             power  price
#  6780   first owner      delhi  \n\n 30 kmpl            28 bhp      0
# ...

# %%
c=b.replace("first owner","1st owner")
c
# Out:
#                                   model_name  model_year       kms_driven  \
# 2133                       Honda CB300R 2021        2021           500 Km
# 4757        Indian Chief Classic 1800cc 2015        2015  Mileage 14 Kmpl
# 6778        Triumph Rocket III Roadster 2016        2016         23000 Km
# 3252           Moto Guzzi Audace 1380cc 2020        2020           900 Km
# 5401            Ducati XDiavel 1262CC S 2017        2017          7000 Km
# 5951                 MV Agusta F3 800cc 2018        2018          2000 Km
# 5586                  BMW S 1000 XR Pro 2017        2017         18000 Km
# 5067  Harley-Davidson Night Rod Special 2015        2015         10800 Km
# 2257       Honda CBR1000RR Fireblade SP 2019        2019          1590 Km
# 5487                Ducati Panigale 959 2019        2019          1300 Km
#
#              owner   location       mileage  \
# 2133     1st owner  bangalore         \n\n
# 4757     1st owner    chennai  \n\n 14 Kmpl
# ...

# %%
a
# Out:
#                             model_name  model_year       kms_driven  \
# 6780               Hyosung GT250R 2013        2013          5000 Km
# 7697         Yamaha YZF-R15 150cc 2011        2011         21200 Km
# 7649          Hero Karizma 223 cc 2008        2008         22000 Km
# 6795  Royal Enfield Classic 500cc 2014        2014         10200 Km
# 6200      Hero Passion Xpro 110cc 2015        2015          9000 Km
# 7802         TVS Apache RTR 160cc 2011        2011  Mileage 60 Kmpl
# 7810          Hero Splendor 100cc 1996        1996         30000 Km
# 7811          Hero Passion 100cc  2005        2005         35000 Km
# 4786          Bajaj  Pulsar 180cc 2009        2009         60000 Km
# 7667         Bajaj Discover 125ST 2013        2013         13299 Km
#
#              owner   location       mileage             power  price
# 6780   first owner      delhi  \n\n 30 kmpl            28 bhp      0
# 7697   first owner      delhi  \n\n 42 kmpl            16 bhp      0
# ...
