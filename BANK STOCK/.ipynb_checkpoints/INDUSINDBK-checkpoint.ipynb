# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
INDUSINDBK=pd.read_csv(r'C:\Users\Nkmanithia\DATA SCIENCE\stock\INDUSINDBK.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 INDUSINDBK=pd.read_csv(r'C:\Users\Nkmanithia\DATA SCIENCE\stock\INDUSINDBK.csv')
#
# NameError: name 'pd' is not defined

# %%
INDUSINDBK
# Out:
#             Date      Symbol Series  Prev Close    Open    High     Low  \
# 0     2000-01-03  INDUSINDBK     EQ       26.80   28.90   28.95   28.00
# 1     2000-01-04  INDUSINDBK     EQ       28.95   30.85   31.25   27.90
# 2     2000-01-05  INDUSINDBK     EQ       30.25   29.90   30.00   27.85
# 3     2000-01-06  INDUSINDBK     EQ       28.15   29.25   29.35   27.95
# 4     2000-01-07  INDUSINDBK     EQ       28.00   27.20   28.00   26.50
# ...          ...         ...    ...         ...     ...     ...     ...
# 4980  2021-04-26  INDUSINDBK     EQ      850.00  857.00  870.95  851.45
# 4981  2021-04-27  INDUSINDBK     EQ      859.55  859.55  886.00  859.00
# 4982  2021-04-28  INDUSINDBK     EQ      882.45  890.00  931.00  888.00
# 4983  2021-04-29  INDUSINDBK     EQ      926.90  936.85  958.85  917.10
# 4984  2021-04-30  INDUSINDBK     EQ      939.45  928.00  948.50  915.10
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
# 0. Describe and Analysis the data and find the corelation in between fields.

# %%
INDUSINDBK.head(5)
# Out:
#          Date      Symbol Series  Prev Close   Open   High    Low   Last  \
# 0  2000-01-03  INDUSINDBK     EQ       26.80  28.90  28.95  28.00  28.95
# 1  2000-01-04  INDUSINDBK     EQ       28.95  30.85  31.25  27.90  30.60
# 2  2000-01-05  INDUSINDBK     EQ       30.25  29.90  30.00  27.85  28.45
# 3  2000-01-06  INDUSINDBK     EQ       28.15  29.25  29.35  27.95  27.95
# 4  2000-01-07  INDUSINDBK     EQ       28.00  27.20  28.00  26.50  27.20
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  28.95  28.69  107224  3.075827e+11     NaN                 NaN          NaN
# 1  30.25  29.12  182693  5.320731e+11     NaN                 NaN          NaN
# 2  28.15  28.72  162820  4.675717e+11     NaN                 NaN          NaN
# 3  28.00  28.55   87901  2.510007e+11     NaN                 NaN          NaN
# 4  27.05  27.09   65684  1.779190e+11     NaN                 NaN          NaN

# %%
INDUSINDBK.index
# Out:
# RangeIndex(start=0, stop=4985, step=1)

# %%
INDUSINDBK.shape
# Out:
# (4985, 15)

# %%
INDUSINDBK.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
INDUSINDBK.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
INDUSINDBK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4985 entries, 0 to 4984
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4985 non-null   object
#  1   Symbol              4985 non-null   object
#  2   Series              4985 non-null   object
#  3   Prev Close          4985 non-null   float64
#  4   Open                4985 non-null   float64
#  5   High                4985 non-null   float64
#  6   Low                 4985 non-null   float64
#  7   Last                4985 non-null   float64
#  8   Close               4985 non-null   float64
#  9   VWAP                4985 non-null   float64
#  10  Volume              4985 non-null   int64
#  11  Turnover            4985 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4797 non-null   float64
#  14  %Deliverble         4797 non-null   float64
# ...

# %%
# This datasheet is having information about the stocks of icici bank wtih colume('Date', 'Symbol', 'Series', 'Prev Close',
'Open', 'High', 'Low', 'Last','Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume','%Deliverble') . 
In this csv file we deal with 3 type of data type(object,float,int ).and it consist 4985 number of rows

# %%
INDUSINDBK.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.999942  0.999802  0.999738  0.999644
# Open                  0.999942  1.000000  0.999844  0.999789  0.999679
# High                  0.999802  0.999844  1.000000  0.999715  0.999845
# Low                   0.999738  0.999789  0.999715  1.000000  0.999835
# Last                  0.999644  0.999679  0.999845  0.999835  1.000000
# Close                 0.999653  0.999688  0.999853  0.999845  0.999993
# VWAP                  0.999790  0.999834  0.999920  0.999909  0.999937
# Volume                0.114715  0.115599  0.121838  0.109391  0.115763
# Turnover              0.363842  0.364564  0.371314  0.357855  0.364792
# Trades                0.017873  0.018933  0.028818  0.006447  0.017304
# Deliverable Volume    0.221308  0.221627  0.227793  0.214681  0.221247
# %Deliverble           0.010698  0.010021  0.006580  0.013770  0.010151
#
# ...

# %%
INDUSINDBK.corr().min()
# Out:
# Prev Close            0.010698
# Open                  0.010021
# High                  0.006580
# Low                   0.006447
# Last                  0.010151
# Close                 0.010076
# VWAP                  0.009831
# Volume               -0.397069
# Turnover             -0.353765
# Trades               -0.447533
# Deliverable Volume   -0.209152
# %Deliverble          -0.447533
# dtype: float64

# %%
I1=INDUSINDBK[INDUSINDBK["Deliverable Volume"]>0]

# %%
I1
# Out:
#             Date      Symbol Series  Prev Close    Open    High     Low  \
# 177   2002-01-01  INDUSINDBK     EQ       10.65   11.15   11.20   10.50
# 178   2002-01-02  INDUSINDBK     EQ       10.60   10.55   10.70   10.30
# 179   2002-01-03  INDUSINDBK     EQ       10.70   10.60   10.75   10.50
# 180   2002-01-04  INDUSINDBK     EQ       10.60   10.55   10.70   10.35
# 181   2002-01-07  INDUSINDBK     EQ       10.40   10.90   10.90   10.40
# ...          ...         ...    ...         ...     ...     ...     ...
# 4980  2021-04-26  INDUSINDBK     EQ      850.00  857.00  870.95  851.45
# 4981  2021-04-27  INDUSINDBK     EQ      859.55  859.55  886.00  859.00
# 4982  2021-04-28  INDUSINDBK     EQ      882.45  890.00  931.00  888.00
# 4983  2021-04-29  INDUSINDBK     EQ      926.90  936.85  958.85  917.10
# 4984  2021-04-30  INDUSINDBK     EQ      939.45  928.00  948.50  915.10
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
I1.head(5)
# Out:
#            Date      Symbol Series  Prev Close   Open   High    Low   Last  \
# 177  2002-01-01  INDUSINDBK     EQ       10.65  11.15  11.20  10.50  10.50
# 178  2002-01-02  INDUSINDBK     EQ       10.60  10.55  10.70  10.30  10.70
# 179  2002-01-03  INDUSINDBK     EQ       10.70  10.60  10.75  10.50  10.75
# 180  2002-01-04  INDUSINDBK     EQ       10.60  10.55  10.70  10.35  10.45
# 181  2002-01-07  INDUSINDBK     EQ       10.40  10.90  10.90  10.40  10.45
#
#      Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 177   10.6  10.70    9751  1.043236e+10     NaN              7300.0
# 178   10.7  10.50    7885  8.278250e+09     NaN              7385.0
# 179   10.6  10.56   17195  1.815738e+10     NaN             16695.0
# 180   10.4  10.52   26940  2.835375e+10     NaN             22080.0
# 181   10.5  10.47    8565  8.970425e+09     NaN              8100.0
#
#      %Deliverble
# 177       0.7486
# 178       0.9366
# 179       0.9709
# 180       0.8196
# ...

# %%
sns.pairplot(INDUSINDBK)

# %%
I1.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.999941  0.999797  0.999731  0.999633
# Open                  0.999941  1.000000  0.999840  0.999784  0.999670
# High                  0.999797  0.999840  1.000000  0.999707  0.999841
# Low                   0.999731  0.999784  0.999707  1.000000  0.999830
# Last                  0.999633  0.999670  0.999841  0.999830  1.000000
# Close                 0.999643  0.999679  0.999849  0.999840  0.999993
# VWAP                  0.999784  0.999829  0.999917  0.999907  0.999935
# Volume                0.103163  0.104058  0.110376  0.097772  0.104226
# Turnover              0.356283  0.357017  0.363876  0.350198  0.357248
# Trades                0.017873  0.018933  0.028818  0.006447  0.017304
# Deliverable Volume    0.221308  0.221627  0.227793  0.214681  0.221247
# %Deliverble           0.010698  0.010021  0.006580  0.013770  0.010151
#
# ...

# %%
I1.corr().min()
# Out:
# Prev Close            0.010698
# Open                  0.010021
# High                  0.006580
# Low                   0.006447
# Last                  0.010151
# Close                 0.010076
# VWAP                  0.009831
# Volume               -0.397069
# Turnover             -0.353765
# Trades               -0.447533
# Deliverable Volume   -0.209152
# %Deliverble          -0.447533
# dtype: float64

# %%
I1.corr().max()
# Out:
# Prev Close            1.0
# Open                  1.0
# High                  1.0
# Low                   1.0
# Last                  1.0
# Close                 1.0
# VWAP                  1.0
# Volume                1.0
# Turnover              1.0
# Trades                1.0
# Deliverable Volume    1.0
# %Deliverble           1.0
# dtype: float64

# %%
# In given data of INDUSINDBANK the Low and volume show max negative reation with the correlation value -0.447533. and Last and 
close value shows positive relationwiyh having correlation 0.999993.

# %%
# 1. Find the patteren accociated with opening ammmount wrt Date Field

# %%
INDUSINDBK.head(5)
# Out:
#          Date      Symbol Series  Prev Close   Open   High    Low   Last  \
# 0  2000-01-03  INDUSINDBK     EQ       26.80  28.90  28.95  28.00  28.95
# 1  2000-01-04  INDUSINDBK     EQ       28.95  30.85  31.25  27.90  30.60
# 2  2000-01-05  INDUSINDBK     EQ       30.25  29.90  30.00  27.85  28.45
# 3  2000-01-06  INDUSINDBK     EQ       28.15  29.25  29.35  27.95  27.95
# 4  2000-01-07  INDUSINDBK     EQ       28.00  27.20  28.00  26.50  27.20
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  28.95  28.69  107224  3.075827e+11     NaN                 NaN          NaN
# 1  30.25  29.12  182693  5.320731e+11     NaN                 NaN          NaN
# 2  28.15  28.72  162820  4.675717e+11     NaN                 NaN          NaN
# 3  28.00  28.55   87901  2.510007e+11     NaN                 NaN          NaN
# 4  27.05  27.09   65684  1.779190e+11     NaN                 NaN          NaN

# %%
INDUSINDBK.Date=pd.to_datetime(INDUSINDBK.Date)
INDUSINDBK['year']=INDUSINDBK['Date'].dt.year
INDUSINDBK['month']=INDUSINDBK['Date'].dt.month
INDUSINDBK['day']=INDUSINDBK['Date'].dt.date

# %%
plt.figure(figsize=(20,5))
plt.plot(INDUSINDBK.year,INDUSINDBK.Open)
plt.xticks(range(2000,2022,1));

# %%
I2=INDUSINDBK[INDUSINDBK.year==2014]
I2.head()
# Out:
#            Date      Symbol Series  Prev Close    Open   High     Low    Last  \
# 3175 2014-01-01  INDUSINDBK     EQ      420.70  422.60  424.6  421.35  424.40
# 3176 2014-01-02  INDUSINDBK     EQ      423.35  423.50  432.9  410.60  411.75
# 3177 2014-01-03  INDUSINDBK     EQ      413.05  413.00  415.5  406.60  414.40
# 3178 2014-01-06  INDUSINDBK     EQ      413.90  414.15  415.0  409.10  412.60
# 3179 2014-01-07  INDUSINDBK     EQ      413.30  418.00  421.5  411.00  419.90
#
#        Close    VWAP   Volume      Turnover   Trades  Deliverable Volume  \
# 3175  423.35  422.81   436060  1.843720e+13   8153.0            173251.0
# 3176  413.05  423.52  1488105  6.302357e+13  27168.0            672473.0
# 3177  413.90  411.00  1744494  7.169814e+13  41944.0            775825.0
# 3178  413.30  412.05  1053536  4.341066e+13  25825.0            389619.0
# 3179  418.85  416.55  1751684  7.296712e+13  39722.0            558145.0
#
#       %Deliverble  year  month         day
# ...

# %%
I3=INDUSINDBK[INDUSINDBK.year==2020]
I3.head()
# Out:
#            Date      Symbol Series  Prev Close     Open     High      Low  \
# 4653 2020-01-01  INDUSINDBK     EQ     1510.00  1512.00  1523.95  1480.80
# 4654 2020-01-02  INDUSINDBK     EQ     1484.30  1491.75  1534.30  1486.10
# 4655 2020-01-03  INDUSINDBK     EQ     1529.00  1524.00  1538.00  1512.10
# 4656 2020-01-06  INDUSINDBK     EQ     1528.85  1515.05  1517.75  1465.45
# 4657 2020-01-07  INDUSINDBK     EQ     1469.40  1488.45  1508.00  1442.20
#
#          Last    Close     VWAP   Volume      Turnover   Trades  \
# 4653  1486.95  1484.30  1494.31  2135253  3.190733e+14  55819.0
# 4654  1533.00  1529.00  1508.49  2365906  3.568937e+14  76221.0
# 4655  1529.00  1528.85  1522.15  2622870  3.992392e+14  65975.0
# 4656  1470.90  1469.40  1490.40  3151046  4.696334e+14  92915.0
# 4657  1458.00  1461.65  1472.17  3572603  5.259482e+14  82614.0
#
#       Deliverable Volume  %Deliverble  year  month         day
# 4653            429833.0       0.2013  2020      1  2020-01-01
# ...

# %%
I1.Open.mean()
# Out:
# 513.5457369189078

# %%
I2.Open.mean()
# Out:
# 560.5862704918032

# %%
INDUSINDBK.Open.mean()
# Out:
# 494.8566599799399

# %%
# The opening ammount in 2014 having mean "560.5862" which is approx double with comparision to mean of opening 
ammount in 2020. But the volume increase with dicrease in opening ammount .

# %%
# 2. Extract the data from jan 2019 to apr 2021 and plot it.

# %%
INDUSINDBK.head(5)
# Out:
#         Date      Symbol Series  Prev Close   Open   High    Low   Last  \
# 0 2000-01-03  INDUSINDBK     EQ       26.80  28.90  28.95  28.00  28.95
# 1 2000-01-04  INDUSINDBK     EQ       28.95  30.85  31.25  27.90  30.60
# 2 2000-01-05  INDUSINDBK     EQ       30.25  29.90  30.00  27.85  28.45
# 3 2000-01-06  INDUSINDBK     EQ       28.15  29.25  29.35  27.95  27.95
# 4 2000-01-07  INDUSINDBK     EQ       28.00  27.20  28.00  26.50  27.20
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  28.95  28.69  107224  3.075827e+11     NaN                 NaN
# 1  30.25  29.12  182693  5.320731e+11     NaN                 NaN
# 2  28.15  28.72  162820  4.675717e+11     NaN                 NaN
# 3  28.00  28.55   87901  2.510007e+11     NaN                 NaN
# 4  27.05  27.09   65684  1.779190e+11     NaN                 NaN
#
#    %Deliverble  year  month         day
# 0          NaN  2000      1  2000-01-03
# 1          NaN  2000      1  2000-01-04
# ...

# %%
I1=INDUSINDBK[INDUSINDBK.year>2018]

# %%
I1.head(5)
# Out:
#            Date      Symbol Series  Prev Close    Open    High      Low  \
# 4408 2019-01-01  INDUSINDBK     EQ      1599.3  1600.0  1605.0  1560.55
# 4409 2019-01-02  INDUSINDBK     EQ      1595.6  1587.6  1598.0  1568.25
# 4410 2019-01-03  INDUSINDBK     EQ      1576.6  1573.0  1580.0  1555.65
# 4411 2019-01-04  INDUSINDBK     EQ      1560.1  1560.8  1571.0  1540.20
# 4412 2019-01-07  INDUSINDBK     EQ      1548.2  1561.0  1610.0  1550.50
#
#          Last    Close     VWAP   Volume      Turnover   Trades  \
# 4408  1594.80  1595.60  1591.48  4043870  6.435739e+14  40222.0
# 4409  1572.05  1576.60  1582.18  1164974  1.843201e+14  48985.0
# 4410  1557.85  1560.10  1565.21   958038  1.499527e+14  40934.0
# 4411  1545.30  1548.20  1550.74  1868151  2.897024e+14  51198.0
# 4412  1558.00  1559.15  1580.51  3991996  6.309385e+14  87535.0
#
#       Deliverable Volume  %Deliverble  year  month         day
# 4408            121070.0       0.0299  2019      1  2019-01-01
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(I1.Date,I1.Open)
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Opening ammount" ,fontdict = {"size":20});

# %%
plt.figure(figsize=(20,5))
plt.plot(I1.Date,I1.Volume,"r");
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Volume" ,fontdict = {"size":20});

# %%
plt.figure(figsize=(20,5))
plt.plot(I1.Date,I1.Trades,"g");
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Trades" ,fontdict = {"size":20});

# %%
# In above graph we easly can see that Trades and Volume show a large increment change and the value of opening ammount start 
drop in the start of 2020 due to the pandemic covid-19.

# %%
# 3. plot the open ammount with Date field after grouping month,yearly and weekly.

# %%
INDUSINDBK.head(5)
# Out:
#         Date      Symbol Series  Prev Close   Open   High    Low   Last  \
# 0 2000-01-03  INDUSINDBK     EQ       26.80  28.90  28.95  28.00  28.95
# 1 2000-01-04  INDUSINDBK     EQ       28.95  30.85  31.25  27.90  30.60
# 2 2000-01-05  INDUSINDBK     EQ       30.25  29.90  30.00  27.85  28.45
# 3 2000-01-06  INDUSINDBK     EQ       28.15  29.25  29.35  27.95  27.95
# 4 2000-01-07  INDUSINDBK     EQ       28.00  27.20  28.00  26.50  27.20
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  28.95  28.69  107224  3.075827e+11     NaN                 NaN
# 1  30.25  29.12  182693  5.320731e+11     NaN                 NaN
# 2  28.15  28.72  162820  4.675717e+11     NaN                 NaN
# 3  28.00  28.55   87901  2.510007e+11     NaN                 NaN
# 4  27.05  27.09   65684  1.779190e+11     NaN                 NaN
#
#    %Deliverble  year  month         day
# 0          NaN  2000      1  2000-01-03
# 1          NaN  2000      1  2000-01-04
# ...

# %%
plt.figure(figsize=(20,5))
plt.scatter(INDUSINDBK.year,INDUSINDBK.Open)
plt.xticks(range(2000,2022));
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.xlabel("year",fontdict = {"size":20})
plt.ylabel("Opening ammount" ,fontdict = {"size":20})
# Out:
# Text(0, 0.5, 'Opening ammount')

# %%
# In scatter graph we see the opening ammount is very large in 2001 to 2018.But the opening ammount in the 
staring 2019 was decrease in large amount due to covid crisis.

# %%
plt.figure(figsize=(20,5))
plt.scatter(INDUSINDBK.month,INDUSINDBK.Open)
plt.xticks(range(0,13));
plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)
plt.xlabel("Month",fontdict = {"size":20})
plt.ylabel("Opening ammount" ,fontdict = {"size":20})
# Out:
# Text(0, 0.5, 'Opening ammount')

# %%
# BY seeing this scatter graph we can easly says month 6,7,8 is opening ammount is high as commper to other months.
