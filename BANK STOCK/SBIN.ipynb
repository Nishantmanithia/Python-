# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
SBIN=pd.read_csv(r'C:\Users\Nkmanithia\DATA SCIENCE\stock\SBIN.csv')

# %%
SBIN.head()
# Out:
#          Date Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  2000-01-03   SBIN     EQ      225.60  236.00  243.65  234.25  243.65
# 1  2000-01-04   SBIN     EQ      243.65  243.65  262.00  238.85  258.00
# 2  2000-01-05   SBIN     EQ      259.10  249.00  264.70  245.00  249.05
# 3  2000-01-06   SBIN     EQ      248.45  252.00  268.00  252.00  260.50
# 4  2000-01-07   SBIN     EQ      261.00  261.50  279.90  255.00  279.00
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  243.65  240.83  2373228  5.715338e+13     NaN                 NaN
# 1  259.10  251.46  4495741  1.130506e+14     NaN                 NaN
# 2  248.45  252.35  3434058  8.666008e+13     NaN                 NaN
# 3  261.00  262.18  6658801  1.745817e+14     NaN                 NaN
# 4  273.30  269.02  7873985  2.118287e+14     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# # 1. Describe and Analysis the data and find the corelation in between fields.

# %%
SBIN.head(5)
# Out:
#          Date Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  2000-01-03   SBIN     EQ      225.60  236.00  243.65  234.25  243.65
# 1  2000-01-04   SBIN     EQ      243.65  243.65  262.00  238.85  258.00
# 2  2000-01-05   SBIN     EQ      259.10  249.00  264.70  245.00  249.05
# 3  2000-01-06   SBIN     EQ      248.45  252.00  268.00  252.00  260.50
# 4  2000-01-07   SBIN     EQ      261.00  261.50  279.90  255.00  279.00
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  243.65  240.83  2373228  5.715338e+13     NaN                 NaN
# 1  259.10  251.46  4495741  1.130506e+14     NaN                 NaN
# 2  248.45  252.35  3434058  8.666008e+13     NaN                 NaN
# 3  261.00  262.18  6658801  1.745817e+14     NaN                 NaN
# 4  273.30  269.02  7873985  2.118287e+14     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
SBIN.index
# Out:
# RangeIndex(start=0, stop=5306, step=1)

# %%
SBIN.shape
# Out:
# (5306, 15)

# %%
SBIN.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
SBIN.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
SBIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4792 non-null   float64
#  14  %Deliverble         4792 non-null   float64
# ...

# %% [markdown]
# ### This datasheet is having information about the stocks of icici bank wtih colume('Date', 'Symbol', 'Series', 'Prev Close','Open', 'High', 'Low', 'Last','Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume','%Deliverble') . In this csv file we deal with 3 type of data type(object,float,int ).and it consist 5306 number of rows

# %%
SBIN.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.998973  0.998787  0.998741  0.998516
# Open                  0.998973  1.000000  0.999728  0.999673  0.999400
# High                  0.998787  0.999728  1.000000  0.999569  0.999712
# Low                   0.998741  0.999673  0.999569  1.000000  0.999715
# Last                  0.998516  0.999400  0.999712  0.999715  1.000000
# Close                 0.998557  0.999439  0.999740  0.999741  0.999989
# VWAP                  0.998825  0.999716  0.999862  0.999854  0.999874
# Volume               -0.363840 -0.364077 -0.363730 -0.364097 -0.363704
# Turnover              0.014226  0.014276  0.016500  0.012719  0.015102
# Trades               -0.336510 -0.336750 -0.333656 -0.339565 -0.336370
# Deliverable Volume   -0.424110 -0.424563 -0.424350 -0.424450 -0.424277
# %Deliverble           0.135158  0.135184  0.134069  0.135353  0.133948
#
# ...

# %%
SBIN.corr().min()
# Out:
# Prev Close           -0.424110
# Open                 -0.424563
# High                 -0.424350
# Low                  -0.424450
# Last                 -0.424277
# Close                -0.424285
# VWAP                 -0.424405
# Volume               -0.364097
# Turnover              0.012719
# Trades               -0.339565
# Deliverable Volume   -0.424563
# %Deliverble          -0.212897
# dtype: float64

# %%
S1=SBIN[SBIN["Deliverable Volume"]>0]

# %%
S1.head()
# Out:
#            Date Symbol Series  Prev Close    Open    High     Low   Last  \
# 498  2002-01-01   SBIN     EQ      181.45  183.00  184.35  182.50  184.0
# 499  2002-01-02   SBIN     EQ      183.45  184.75  189.50  184.75  189.5
# 500  2002-01-03   SBIN     EQ      188.60  191.00  200.90  189.05  199.5
# 501  2002-01-04   SBIN     EQ      199.10  200.55  204.35  200.00  202.0
# 502  2002-01-07   SBIN     EQ      202.70  204.50  204.50  193.10  194.0
#
#       Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 498  183.45  183.30  153925  2.821462e+12     NaN             87724.0
# 499  188.60  187.16  213441  3.994780e+12     NaN             92471.0
# 500  199.10  195.85  589106  1.153781e+13     NaN            360097.0
# 501  202.70  202.57  397013  8.042326e+12     NaN            244263.0
# 502  194.50  197.25  218259  4.305251e+12     NaN            105606.0
#
#      %Deliverble
# 498       0.5699
# 499       0.4332
# 500       0.6113
# 501       0.6153
# ...

# %%
sns.pairplot(SBIN)

# %%
S1.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.998881  0.998678  0.998631  0.998384
# Open                  0.998881  1.000000  0.999704  0.999646  0.999348
# High                  0.998678  0.999704  1.000000  0.999533  0.999688
# Low                   0.998631  0.999646  0.999533  1.000000  0.999691
# Last                  0.998384  0.999348  0.999688  0.999691  1.000000
# Close                 0.998429  0.999391  0.999718  0.999720  0.999988
# VWAP                  0.998721  0.999693  0.999851  0.999841  0.999864
# Volume               -0.432993 -0.433222 -0.432904 -0.433188 -0.432881
# Turnover             -0.069248 -0.069179 -0.066809 -0.070843 -0.068354
# Trades               -0.336510 -0.336750 -0.333656 -0.339565 -0.336370
# Deliverable Volume   -0.424110 -0.424563 -0.424350 -0.424450 -0.424277
# %Deliverble           0.135158  0.135184  0.134069  0.135353  0.133948
#
# ...

# %%
S1.corr().min()
# Out:
# Prev Close           -0.432993
# Open                 -0.433222
# High                 -0.432904
# Low                  -0.433188
# Last                 -0.432881
# Close                -0.432901
# VWAP                 -0.433034
# Volume               -0.433222
# Turnover             -0.070843
# Trades               -0.339565
# Deliverable Volume   -0.424563
# %Deliverble          -0.212897
# dtype: float64

# %%
S1.corr().max()
# Out:
# Prev Close            1.0
# Open                  1.0
# High                  1.0
# Low                   1.0
# Last                  1.0
# Close                 1.0
# VWAP                  1.0
# Volume                1.0
# Turnover              1.0
# Trades                1.0
# Deliverable Volume    1.0
# %Deliverble           1.0
# dtype: float64

# %% [markdown]
# ### In given data of SBIN the Low and volume show max negative reation with the correlation value -0.433222. and Last and close value shows positive relationwiyh having correlation 0.999988.

# %% [markdown]
# # 2. Find the patteren accociated with opening ammmount wrt Date Field

# %%
SBIN.head(5)
# Out:
#          Date Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  2000-01-03   SBIN     EQ      225.60  236.00  243.65  234.25  243.65
# 1  2000-01-04   SBIN     EQ      243.65  243.65  262.00  238.85  258.00
# 2  2000-01-05   SBIN     EQ      259.10  249.00  264.70  245.00  249.05
# 3  2000-01-06   SBIN     EQ      248.45  252.00  268.00  252.00  260.50
# 4  2000-01-07   SBIN     EQ      261.00  261.50  279.90  255.00  279.00
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  243.65  240.83  2373228  5.715338e+13     NaN                 NaN
# 1  259.10  251.46  4495741  1.130506e+14     NaN                 NaN
# 2  248.45  252.35  3434058  8.666008e+13     NaN                 NaN
# 3  261.00  262.18  6658801  1.745817e+14     NaN                 NaN
# 4  273.30  269.02  7873985  2.118287e+14     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
SBIN.Date=pd.to_datetime(SBIN.Date)
SBIN['year']=SBIN['Date'].dt.year
SBIN['month']=SBIN['Date'].dt.month
SBIN['day']=SBIN['Date'].dt.date

# %%
plt.figure(figsize=(20,5))
plt.plot(SBIN.year,SBIN.Open)
plt.xticks(range(2000,2022,1));

# %%
S2=SBIN[SBIN.year==2014]
S2.head()
# Out:
#            Date Symbol Series  Prev Close    Open    High      Low    Last  \
# 3496 2014-01-01   SBIN     EQ     1766.50  1772.0  1774.9  1761.25  1770.0
# 3497 2014-01-02   SBIN     EQ     1765.05  1765.9  1806.0  1732.20  1736.0
# 3498 2014-01-03   SBIN     EQ     1742.60  1727.0  1736.0  1711.00  1719.0
# 3499 2014-01-06   SBIN     EQ     1719.65  1721.9  1724.0  1682.00  1685.0
# 3500 2014-01-07   SBIN     EQ     1688.15  1692.9  1702.0  1655.00  1656.2
#
#         Close     VWAP   Volume      Turnover   Trades  Deliverable Volume  \
# 3496  1765.05  1767.01   590478  1.043383e+14  26013.0             83547.0
# 3497  1742.60  1778.15  1945190  3.458847e+14  84897.0            466573.0
# 3498  1719.65  1721.21  1375959  2.368309e+14  58063.0            314028.0
# 3499  1688.15  1695.02  1390783  2.357403e+14  66356.0            381718.0
# 3500  1661.40  1670.51  1735291  2.898813e+14  79314.0            483821.0
#
#       %Deliverble  year  month         day
# ...

# %%
S3=SBIN[SBIN.year==2020]
S3.head()
# Out:
#            Date Symbol Series  Prev Close    Open    High     Low   Last  \
# 4974 2020-01-01   SBIN     EQ      333.75  334.70  335.95  332.15  335.0
# 4975 2020-01-02   SBIN     EQ      334.45  334.50  339.85  333.35  338.8
# 4976 2020-01-03   SBIN     EQ      339.30  337.95  337.95  332.00  334.0
# 4977 2020-01-06   SBIN     EQ      333.70  331.70  331.70  317.70  318.4
# 4978 2020-01-07   SBIN     EQ      319.00  324.45  327.00  315.40  317.9
#
#        Close    VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 4974  334.45  334.03  17379320  5.805130e+14   99108.0           1850790.0
# 4975  339.30  336.81  20324236  6.845341e+14  123189.0           4239894.0
# 4976  333.70  335.08  21853208  7.322600e+14  139793.0           6309081.0
# 4977  319.00  322.03  35645325  1.147882e+15  280646.0           8731362.0
# 4978  318.40  320.38  50966826  1.632868e+15  310782.0           9993754.0
#
#       %Deliverble  year  month         day
# ...

# %%
S1.Open.mean()
# Out:
# 1046.4083681135291

# %%
S2.Open.mean()
# Out:
# 1997.1625000000004

# %%
SBIN.Open.mean()
# Out:
# 967.1821145872661

# %% [markdown]
# ### The opening ammount in 2014 having mean "1997.162" which is approx double with comparision to mean of opening ammount in 2020. But the volume increase with dicrease in opening ammount .

# %% [markdown]
# # 3. Extract the data from jan 2019 to apr 2021 and plot it.

# %%
SBIN.head(5)
# Out:
#         Date Symbol Series  Prev Close    Open    High     Low    Last  \
# 0 2000-01-03   SBIN     EQ      225.60  236.00  243.65  234.25  243.65
# 1 2000-01-04   SBIN     EQ      243.65  243.65  262.00  238.85  258.00
# 2 2000-01-05   SBIN     EQ      259.10  249.00  264.70  245.00  249.05
# 3 2000-01-06   SBIN     EQ      248.45  252.00  268.00  252.00  260.50
# 4 2000-01-07   SBIN     EQ      261.00  261.50  279.90  255.00  279.00
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  243.65  240.83  2373228  5.715338e+13     NaN                 NaN
# 1  259.10  251.46  4495741  1.130506e+14     NaN                 NaN
# 2  248.45  252.35  3434058  8.666008e+13     NaN                 NaN
# 3  261.00  262.18  6658801  1.745817e+14     NaN                 NaN
# 4  273.30  269.02  7873985  2.118287e+14     NaN                 NaN
#
#    %Deliverble  year  month         day
# 0          NaN  2000      1  2000-01-03
# 1          NaN  2000      1  2000-01-04
# ...

# %%
S1=SBIN[SBIN.year>2018]

# %%
S1.head(5)
# Out:
#            Date Symbol Series  Prev Close    Open    High     Low    Last  \
# 4729 2019-01-01   SBIN     EQ      295.90  297.50  300.70  293.85  300.70
# 4730 2019-01-02   SBIN     EQ      299.60  299.10  302.50  293.10  293.80
# 4731 2019-01-03   SBIN     EQ      293.90  295.00  295.55  290.10  291.05
# 4732 2019-01-04   SBIN     EQ      291.10  292.10  299.00  291.50  297.30
# 4733 2019-01-07   SBIN     EQ      297.65  301.05  301.50  295.20  296.55
#
#        Close    VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 4729  299.60  296.77  11837127  3.512877e+14   69723.0           1668134.0
# 4730  293.90  298.20  25559853  7.622010e+14  162196.0           7019907.0
# 4731  291.10  292.87  17548347  5.139324e+14  110626.0           6361787.0
# 4732  297.65  296.18  19514041  5.779686e+14  142962.0           4963982.0
# 4733  296.30  298.25  14579399  4.348321e+14  113554.0           4817960.0
#
#       %Deliverble  year  month         day
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(S1.Date,S1.Open)
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Opening ammount" ,fontdict = {"size":20});

# %%
plt.figure(figsize=(20,5))
plt.plot(S1.Date,S1.Volume,"r");
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Volume" ,fontdict = {"size":20});

# %%
plt.figure(figsize=(20,5))
plt.plot(S1.Date,S1.Trades,"g");
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Trades" ,fontdict = {"size":20});

# %% [markdown]
# ### In above graph we easly can see that Trades and Volume show a large increment change and the value of opening ammount start drop in the start of 2020 due to the pandemic covid-19.

# %% [markdown]
# # 4. Plot the open ammount with Date field after grouping month and yearly .

# %%
SBIN.head(5)
# Out:
#         Date Symbol Series  Prev Close    Open    High     Low    Last  \
# 0 2000-01-03   SBIN     EQ      225.60  236.00  243.65  234.25  243.65
# 1 2000-01-04   SBIN     EQ      243.65  243.65  262.00  238.85  258.00
# 2 2000-01-05   SBIN     EQ      259.10  249.00  264.70  245.00  249.05
# 3 2000-01-06   SBIN     EQ      248.45  252.00  268.00  252.00  260.50
# 4 2000-01-07   SBIN     EQ      261.00  261.50  279.90  255.00  279.00
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  243.65  240.83  2373228  5.715338e+13     NaN                 NaN
# 1  259.10  251.46  4495741  1.130506e+14     NaN                 NaN
# 2  248.45  252.35  3434058  8.666008e+13     NaN                 NaN
# 3  261.00  262.18  6658801  1.745817e+14     NaN                 NaN
# 4  273.30  269.02  7873985  2.118287e+14     NaN                 NaN
#
#    %Deliverble  year  month         day
# 0          NaN  2000      1  2000-01-03
# 1          NaN  2000      1  2000-01-04
# ...

# %%
plt.figure(figsize=(20,5))
plt.scatter(SBIN.year,SBIN.Open)
plt.xticks(range(2000,2022));
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.xlabel("year",fontdict = {"size":20})
plt.ylabel("Opening ammount" ,fontdict = {"size":20})
# Out:
# Text(0, 0.5, 'Opening ammount')

# %% [markdown]
# ### In scatter graph we see the opening ammount is very large in 2010 to 2014 as compare to 2000.But the opening ammount in the staring 2015 was decrease in large amount.

# %%
plt.figure(figsize=(20,5))
plt.scatter(SBIN.month,SBIN.Open)
plt.xticks(range(0,13));
plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)
plt.xlabel("Month",fontdict = {"size":20})
plt.ylabel("Opening ammount" ,fontdict = {"size":20})
# Out:
# Text(0, 0.5, 'Opening ammount')

# %% [markdown]
# ### BY seeing this scatter graph we can easly says month 9,10,11 is opening ammount is high as commper to other months.
