# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
KOTAKBANK=pd.read_csv(r'C:\Users\Nkmanithia\DATA SCIENCE\stock\KOTAKBANK.csv')

# %%
KOTAKBANK
# Out:
#             Date     Symbol Series  Prev Close    Open     High      Low  \
# 0     2000-01-03   KOTAKMAH     EQ      212.35   220.0   229.35   220.00
# 1     2000-01-04   KOTAKMAH     EQ      229.35   247.7   247.70   225.25
# 2     2000-01-05   KOTAKMAH     EQ      246.95   229.0   240.00   227.20
# 3     2000-01-06   KOTAKMAH     EQ      228.40   235.1   239.00   217.00
# 4     2000-01-07   KOTAKMAH     EQ      225.90   213.0   219.00   207.85
# ...          ...        ...    ...         ...     ...      ...      ...
# 4980  2021-04-26  KOTAKBANK     EQ     1734.20  1740.0  1783.00  1733.30
# 4981  2021-04-27  KOTAKBANK     EQ     1759.65  1750.0  1762.60  1724.55
# 4982  2021-04-28  KOTAKBANK     EQ     1750.30  1762.5  1824.00  1754.00
# 4983  2021-04-29  KOTAKBANK     EQ     1811.45  1825.1  1845.45  1780.55
# 4984  2021-04-30  KOTAKBANK     EQ     1805.00  1780.0  1802.00  1739.45
#
#          Last    Close     VWAP   Volume      Turnover    Trades  \
# ...

# %% [markdown]
# # 1. Describe and Analysis the data and find the corelation in between fields.

# %%
KOTAKBANK.head(5)
# Out:
#          Date    Symbol Series  Prev Close   Open    High     Low    Last  \
# 0  2000-01-03  KOTAKMAH     EQ      212.35  220.0  229.35  220.00  229.35
# 1  2000-01-04  KOTAKMAH     EQ      229.35  247.7  247.70  225.25  247.70
# 2  2000-01-05  KOTAKMAH     EQ      246.95  229.0  240.00  227.20  228.00
# 3  2000-01-06  KOTAKMAH     EQ      228.40  235.1  239.00  217.00  224.95
# 4  2000-01-07  KOTAKMAH     EQ      225.90  213.0  219.00  207.85  207.85
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  229.35  229.13    7086  1.623640e+11     NaN                 NaN
# 1  246.95  244.12   73681  1.798729e+12     NaN                 NaN
# 2  228.40  233.75  105799  2.473093e+12     NaN                 NaN
# 3  225.90  226.84   40202  9.119546e+11     NaN                 NaN
# 4  208.85  209.94   24463  5.135747e+11     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
KOTAKBANK.index
# Out:
# RangeIndex(start=0, stop=4985, step=1)

# %%
KOTAKBANK.shape
# Out:
# (4985, 15)

# %%
KOTAKBANK.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
KOTAKBANK.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
KOTAKBANK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4985 entries, 0 to 4984
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4985 non-null   object
#  1   Symbol              4985 non-null   object
#  2   Series              4985 non-null   object
#  3   Prev Close          4985 non-null   float64
#  4   Open                4985 non-null   float64
#  5   High                4985 non-null   float64
#  6   Low                 4985 non-null   float64
#  7   Last                4985 non-null   float64
#  8   Close               4985 non-null   float64
#  9   VWAP                4985 non-null   float64
#  10  Volume              4985 non-null   int64
#  11  Turnover            4985 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4789 non-null   float64
#  14  %Deliverble         4789 non-null   float64
# ...

# %% [markdown]
# ### This datasheet is having information about the stocks of icici bank wtih colume('Date', 'Symbol', 'Series', 'Prev Close','Open', 'High', 'Low', 'Last','Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume','%Deliverble') . In this csv file we deal with 3 type of data type(object,float,int ).and it consist 4985 number of rows

# %%
KOTAKBANK.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.999332  0.999027  0.998906  0.998759
# Open                  0.999332  1.000000  0.999553  0.999437  0.999205
# High                  0.999027  0.999553  1.000000  0.999132  0.999614
# Low                   0.998906  0.999437  0.999132  1.000000  0.999458
# Last                  0.998759  0.999205  0.999614  0.999458  1.000000
# Close                 0.998777  0.999225  0.999625  0.999496  0.999980
# VWAP                  0.999100  0.999567  0.999764  0.999683  0.999831
# Volume                0.419724  0.419438  0.424957  0.415826  0.421682
# Turnover              0.472247  0.472346  0.476936  0.469595  0.474397
# Trades                0.575138  0.576064  0.587762  0.565678  0.579062
# Deliverable Volume    0.333434  0.332842  0.335050  0.330600  0.333359
# %Deliverble          -0.061519 -0.062035 -0.068404 -0.056901 -0.063075
#
# ...

# %%
KOTAKBANK.corr().min()
# Out:
# Prev Close           -0.061519
# Open                 -0.062035
# High                 -0.068404
# Low                  -0.056901
# Last                 -0.063075
# Close                -0.063039
# VWAP                 -0.063344
# Volume               -0.039912
# Turnover             -0.025809
# Trades               -0.200101
# Deliverable Volume    0.123205
# %Deliverble          -0.200101
# dtype: float64

# %%
K1=KOTAKBANK[KOTAKBANK["Deliverable Volume"]>0]

# %%
K1.head()
# Out:
#            Date    Symbol Series  Prev Close   Open   High    Low   Last  \
# 177  2002-01-01  KOTAKMAH     EQ       50.65  49.75  50.85  48.00  48.05
# 178  2002-01-02  KOTAKMAH     EQ       49.10  50.00  52.50  48.85  52.00
# 179  2002-01-03  KOTAKMAH     EQ       51.85  51.00  52.00  50.90  51.00
# 180  2002-01-04  KOTAKMAH     EQ       51.50  51.30  51.50  50.00  50.00
# 181  2002-01-07  KOTAKMAH     EQ       50.60  50.50  60.75  50.50  60.75
#
#      Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 177  49.10  49.28   10010  4.932465e+10     NaN              7410.0
# 178  51.85  50.81    9060  4.603554e+10     NaN              8033.0
# 179  51.50  51.34   10320  5.298414e+10     NaN              6927.0
# 180  50.60  50.80    6765  3.436528e+10     NaN              4930.0
# 181  58.95  56.55   41349  2.338161e+11     NaN             32778.0
#
#      %Deliverble
# 177       0.7403
# 178       0.8866
# 179       0.6712
# 180       0.7288
# 181       0.7927

# %%
sns.pairplot(KOTAKBANK)

# %%
K1.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.999278  0.998947  0.998817  0.998658
# Open                  0.999278  1.000000  0.999517  0.999393  0.999141
# High                  0.998947  0.999517  1.000000  0.999063  0.999584
# Low                   0.998817  0.999393  0.999063  1.000000  0.999414
# Last                  0.998658  0.999141  0.999584  0.999414  1.000000
# Close                 0.998677  0.999163  0.999596  0.999456  0.999979
# VWAP                  0.999027  0.999533  0.999746  0.999658  0.999817
# Volume                0.409812  0.409514  0.415313  0.405712  0.411858
# Turnover              0.471234  0.471337  0.476205  0.468414  0.473487
# Trades                0.575138  0.576064  0.587762  0.565678  0.579062
# Deliverable Volume    0.333434  0.332842  0.335050  0.330600  0.333359
# %Deliverble          -0.061519 -0.062035 -0.068404 -0.056901 -0.063075
#
# ...

# %%
K1.corr().min()
# Out:
# Prev Close           -0.061519
# Open                 -0.062035
# High                 -0.068404
# Low                  -0.056901
# Last                 -0.063075
# Close                -0.063039
# VWAP                 -0.063344
# Volume               -0.039912
# Turnover             -0.025809
# Trades               -0.200101
# Deliverable Volume    0.123205
# %Deliverble          -0.200101
# dtype: float64

# %%
K1.corr().max()
# Out:
# Prev Close            1.0
# Open                  1.0
# High                  1.0
# Low                   1.0
# Last                  1.0
# Close                 1.0
# VWAP                  1.0
# Volume                1.0
# Turnover              1.0
# Trades                1.0
# Deliverable Volume    1.0
# %Deliverble           1.0
# dtype: float64

# %% [markdown]
# ### In given data of KOTAKBANK the Low and volume show max negative reation with the correlation value -0.068404. and Last and close value shows positive relationwiyh having correlation 0.999979.

# %% [markdown]
# # 2. Find the patteren accociated with opening ammmount wrt Date Field

# %%
KOTAKBANK.head(5)
# Out:
#          Date    Symbol Series  Prev Close   Open    High     Low    Last  \
# 0  2000-01-03  KOTAKMAH     EQ      212.35  220.0  229.35  220.00  229.35
# 1  2000-01-04  KOTAKMAH     EQ      229.35  247.7  247.70  225.25  247.70
# 2  2000-01-05  KOTAKMAH     EQ      246.95  229.0  240.00  227.20  228.00
# 3  2000-01-06  KOTAKMAH     EQ      228.40  235.1  239.00  217.00  224.95
# 4  2000-01-07  KOTAKMAH     EQ      225.90  213.0  219.00  207.85  207.85
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  229.35  229.13    7086  1.623640e+11     NaN                 NaN
# 1  246.95  244.12   73681  1.798729e+12     NaN                 NaN
# 2  228.40  233.75  105799  2.473093e+12     NaN                 NaN
# 3  225.90  226.84   40202  9.119546e+11     NaN                 NaN
# 4  208.85  209.94   24463  5.135747e+11     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
KOTAKBANK.Date=pd.to_datetime(KOTAKBANK.Date)
KOTAKBANK['year']=KOTAKBANK['Date'].dt.year
KOTAKBANK['month']=KOTAKBANK['Date'].dt.month
KOTAKBANK['day']=KOTAKBANK['Date'].dt.date

# %%
plt.figure(figsize=(20,5))
plt.plot(KOTAKBANK.year,KOTAKBANK.Open)
plt.xticks(range(2000,2022,1));

# %%
K2=KOTAKBANK[KOTAKBANK.year==2014]
K2.head()
# Out:
#            Date     Symbol Series  Prev Close   Open    High     Low    Last  \
# 3175 2014-01-01  KOTAKBANK     EQ      728.25  732.0  732.05  720.75  723.80
# 3176 2014-01-02  KOTAKBANK     EQ      722.55  722.6  731.45  703.00  705.50
# 3177 2014-01-03  KOTAKBANK     EQ      707.40  707.1  716.30  696.60  713.00
# 3178 2014-01-06  KOTAKBANK     EQ      712.55  710.0  717.00  705.60  712.00
# 3179 2014-01-07  KOTAKBANK     EQ      714.10  712.0  715.00  700.00  707.65
#
#        Close    VWAP  Volume      Turnover   Trades  Deliverable Volume  \
# 3175  722.55  724.09  392768  2.844009e+13   9567.0            253455.0
# 3176  707.40  720.98  456139  3.288690e+13  10105.0            189678.0
# 3177  712.55  711.03  572567  4.071118e+13  21391.0            286840.0
# 3178  714.10  711.31  446715  3.177533e+13  12691.0            284815.0
# 3179  708.15  705.43  643794  4.541518e+13  29097.0            344371.0
#
#       %Deliverble  year  month         day
# ...

# %%
K3=KOTAKBANK[KOTAKBANK.year==2020]
K3.head()
# Out:
#            Date     Symbol Series  Prev Close     Open     High      Low  \
# 4653 2020-01-01  KOTAKBANK     EQ     1684.35  1689.00  1696.75  1672.00
# 4654 2020-01-02  KOTAKBANK     EQ     1674.05  1680.00  1683.50  1664.65
# 4655 2020-01-03  KOTAKBANK     EQ     1671.55  1670.95  1673.00  1645.55
# 4656 2020-01-06  KOTAKBANK     EQ     1657.10  1657.10  1657.45  1638.60
# 4657 2020-01-07  KOTAKBANK     EQ     1652.55  1661.05  1674.75  1650.40
#
#          Last    Close     VWAP   Volume      Turnover   Trades  \
# 4653  1673.15  1674.05  1679.00  1475056  2.476625e+14  43248.0
# 4654  1671.50  1671.55  1669.98  1852089  3.092952e+14  56954.0
# 4655  1659.05  1657.10  1657.75  1594089  2.642596e+14  83688.0
# 4656  1653.80  1652.55  1647.07  1480087  2.437811e+14  64555.0
# 4657  1668.00  1670.85  1662.94  2497931  4.153901e+14  62054.0
#
#       Deliverable Volume  %Deliverble  year  month         day
# 4653            671941.0       0.4555  2020      1  2020-01-01
# ...

# %%
K1.Open.mean()
# Out:
# 722.015994988516

# %%
K2.Open.mean()
# Out:
# 915.3737704918033

# %%
KOTAKBANK.Open.mean()
# Out:
# 697.1549247743235

# %% [markdown]
# ### The opening ammount in 2014 having mean "915.3733" which is approx double with comparision to mean of opening ammount in 2020. But the volume increase with dicrease in opening ammount .

# %% [markdown]
# # 3. Extract the data from jan 2019 to apr 2021 and plot it.

# %%
KOTAKBANK.head(5)
# Out:
#         Date    Symbol Series  Prev Close   Open    High     Low    Last  \
# 0 2000-01-03  KOTAKMAH     EQ      212.35  220.0  229.35  220.00  229.35
# 1 2000-01-04  KOTAKMAH     EQ      229.35  247.7  247.70  225.25  247.70
# 2 2000-01-05  KOTAKMAH     EQ      246.95  229.0  240.00  227.20  228.00
# 3 2000-01-06  KOTAKMAH     EQ      228.40  235.1  239.00  217.00  224.95
# 4 2000-01-07  KOTAKMAH     EQ      225.90  213.0  219.00  207.85  207.85
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  229.35  229.13    7086  1.623640e+11     NaN                 NaN
# 1  246.95  244.12   73681  1.798729e+12     NaN                 NaN
# 2  228.40  233.75  105799  2.473093e+12     NaN                 NaN
# 3  225.90  226.84   40202  9.119546e+11     NaN                 NaN
# 4  208.85  209.94   24463  5.135747e+11     NaN                 NaN
#
#    %Deliverble  year  month         day
# 0          NaN  2000      1  2000-01-03
# ...

# %%
K1=KOTAKBANK[KOTAKBANK.year>2018]

# %%
K1.head(5)
# Out:
#            Date     Symbol Series  Prev Close     Open     High      Low  \
# 4408 2019-01-01  KOTAKBANK     EQ     1256.50  1254.00  1256.00  1242.25
# 4409 2019-01-02  KOTAKBANK     EQ     1250.45  1247.90  1248.25  1227.00
# 4410 2019-01-03  KOTAKBANK     EQ     1240.60  1240.00  1251.00  1227.65
# 4411 2019-01-04  KOTAKBANK     EQ     1235.25  1238.00  1252.00  1230.00
# 4412 2019-01-07  KOTAKBANK     EQ     1247.95  1250.95  1254.00  1241.00
#
#         Last    Close     VWAP   Volume      Turnover   Trades  \
# 4408  1249.0  1250.45  1249.93  1202580  1.503135e+14  29498.0
# 4409  1241.0  1240.60  1239.11  1713677  2.123441e+14  50162.0
# 4410  1233.0  1235.25  1236.83  1825888  2.258314e+14  40004.0
# 4411  1245.1  1247.95  1242.01  1468796  1.824257e+14  50590.0
# 4412  1244.2  1246.60  1247.16  1211456  1.510880e+14  30308.0
#
#       Deliverable Volume  %Deliverble  year  month         day
# 4408            317097.0       0.2637  2019      1  2019-01-01
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(K1.Date,K1.Open)
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Opening ammount" ,fontdict = {"size":20});

# %%
plt.figure(figsize=(20,5))
plt.plot(K1.Date,K1.Volume,"r");
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Volume" ,fontdict = {"size":20});

# %%
plt.figure(figsize=(20,5))
plt.plot(K1.Date,K1.Trades,"g");
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Trades" ,fontdict = {"size":20});

# %% [markdown]
# ### In above graph we easly can see that Trades and Volume show a large increment change and the value of opening ammount start drop in the start of 2020 due to the pandemic covid-19.

# %% [markdown]
# # 4. Plot the open ammount with Date field after grouping month and yearly .

# %%
KOTAKBANK.head(5)
# Out:
#         Date    Symbol Series  Prev Close   Open    High     Low    Last  \
# 0 2000-01-03  KOTAKMAH     EQ      212.35  220.0  229.35  220.00  229.35
# 1 2000-01-04  KOTAKMAH     EQ      229.35  247.7  247.70  225.25  247.70
# 2 2000-01-05  KOTAKMAH     EQ      246.95  229.0  240.00  227.20  228.00
# 3 2000-01-06  KOTAKMAH     EQ      228.40  235.1  239.00  217.00  224.95
# 4 2000-01-07  KOTAKMAH     EQ      225.90  213.0  219.00  207.85  207.85
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  229.35  229.13    7086  1.623640e+11     NaN                 NaN
# 1  246.95  244.12   73681  1.798729e+12     NaN                 NaN
# 2  228.40  233.75  105799  2.473093e+12     NaN                 NaN
# 3  225.90  226.84   40202  9.119546e+11     NaN                 NaN
# 4  208.85  209.94   24463  5.135747e+11     NaN                 NaN
#
#    %Deliverble  year  month         day
# 0          NaN  2000      1  2000-01-03
# ...

# %%
plt.figure(figsize=(20,5))
plt.scatter(KOTAKBANK.year,KOTAKBANK.Open)
plt.xticks(range(2000,2022));
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.xlabel("year",fontdict = {"size":20})
plt.ylabel("Opening ammount" ,fontdict = {"size":20})
# Out:
# Text(0, 0.5, 'Opening ammount')

# %% [markdown]
# ### In scatter graph we see the opening ammount is very large in 2010 to 2014 as compare to 2000.But the opening ammount in the staring 2015 was decrease in large amount.

# %%
plt.figure(figsize=(20,5))
plt.scatter(KOTAKBANK.month,KOTAKBANK.Open)
plt.xticks(range(0,13));
plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)
plt.xlabel("Month",fontdict = {"size":20})
plt.ylabel("Opening ammount" ,fontdict = {"size":20})
# Out:
# Text(0, 0.5, 'Opening ammount')

# %% [markdown]
# ### BY seeing this scatter graph we can easly says month 10,11,12 is opening ammount is high as commper to other months.
