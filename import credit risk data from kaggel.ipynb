# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import opendatasets as od
import seaborn as sns

# %%
dataset_url ="https://www.kaggle.com/datasets/ranadeep/credit-risk-dataset"
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: nishantmanithia
# Your Kaggle Key: ········
# 2023-02-17 14:58:14,817 WARNING Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /kaggle-data-sets/1404394/2327131/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230217%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230217T092756Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 101M/101M [10:00<00:00, 177kB/s]

# %%
df=pd.read_csv(r"C:\Users\Nkmanithia\credit-risk-dataset\loan\loan.csv")
# Out:
# C:\Users\Nkmanithia\AppData\Local\Temp\ipykernel_4844\560270653.py:1: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\Nkmanithia\credit-risk-dataset\loan\loan.csv")

# %%
df
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0        1077501    1296599     5000.0       5000.0           4975.0
# 1        1077430    1314167     2500.0       2500.0           2500.0
# 2        1077175    1313524     2400.0       2400.0           2400.0
# 3        1076863    1277178    10000.0      10000.0          10000.0
# 4        1075358    1311748     3000.0       3000.0           3000.0
# ...          ...        ...        ...          ...              ...
# 887374  36371250   39102635    10000.0      10000.0          10000.0
# 887375  36441262   39152692    24000.0      24000.0          24000.0
# 887376  36271333   38982739    13000.0      13000.0          13000.0
# 887377  36490806   39222577    12000.0      12000.0          12000.0
# 887378  36271262   38982659    20000.0      20000.0          20000.0
#
#               term  int_rate  installment grade sub_grade  ... total_bal_il  \
# ...

# %%
df.tail()
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 887374  36371250   39102635    10000.0      10000.0          10000.0
# 887375  36441262   39152692    24000.0      24000.0          24000.0
# 887376  36271333   38982739    13000.0      13000.0          13000.0
# 887377  36490806   39222577    12000.0      12000.0          12000.0
# 887378  36271262   38982659    20000.0      20000.0          20000.0
#
#               term  int_rate  installment grade sub_grade  ... total_bal_il  \
# 887374   36 months     11.99       332.10     B        B5  ...          NaN
# 887375   36 months     11.99       797.03     B        B5  ...          NaN
# 887376   60 months     15.99       316.07     D        D2  ...          NaN
# 887377   60 months     19.99       317.86     E        E3  ...          NaN
# 887378   36 months     11.99       664.20     B        B5  ...          NaN
#
#        il_util open_rv_12m  open_rv_24m max_bal_bc all_util total_rev_hi_lim  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           887379 non-null  int64
#  1   member_id                    887379 non-null  int64
#  2   loan_amnt                    887379 non-null  float64
#  3   funded_amnt                  887379 non-null  float64
#  4   funded_amnt_inv              887379 non-null  float64
#  5   term                         887379 non-null  object
#  6   int_rate                     887379 non-null  float64
#  7   installment                  887379 non-null  float64
#  8   grade                        887379 non-null  object
#  9   sub_grade                    887379 non-null  object
#  10  emp_title                    835917 non-null  object
#  11  emp_length                   842554 non-null  object
# ...

# %%
df.column()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df.column()
#
# File ~\AppData\anconda\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'
