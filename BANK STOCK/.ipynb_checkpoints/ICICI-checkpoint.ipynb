# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
icici=pd.read_csv(r'C:\Users\Nkmanithia\DATA SCIENCE\stock\ICICIBANK.csv')

# %% [markdown]
# # 1.Describe and Analysis the data and find the corelation in between fields

# %%
icici.head()
# Out:
#          Date     Symbol Series  Prev Close   Open   High    Low   Last  \
# 0  2000-01-03  ICICIBANK     EQ       69.20  74.35  74.75  71.40  74.75
# 1  2000-01-04  ICICIBANK     EQ       74.75  73.05  78.50  71.00  73.25
# 2  2000-01-05  ICICIBANK     EQ       73.05  70.00  73.50  67.50  70.00
# 3  2000-01-06  ICICIBANK     EQ       69.50  71.00  74.00  69.55  69.75
# 4  2000-01-07  ICICIBANK     EQ       70.05  69.00  72.50  66.00  67.00
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  74.75  73.20  286260  2.095439e+12     NaN                 NaN          NaN
# 1  73.05  73.38  296264  2.173893e+12     NaN                 NaN          NaN
# 2  69.50  70.85  227624  1.612794e+12     NaN                 NaN          NaN
# 3  70.05  72.04  275149  1.982121e+12     NaN                 NaN          NaN
# 4  67.40  68.72  138809  9.538882e+11     NaN                 NaN          NaN

# %%
icici.index
# Out:
# RangeIndex(start=0, stop=5306, step=1)

# %%
icici.shape
# Out:
# (5306, 15)

# %%
icici.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
icici.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
icici.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4789 non-null   float64
#  14  %Deliverble         4789 non-null   float64
# ...

# %% [markdown]
# ### This datasheet is having information about the stocks of icici bank wtih colume('Date', 'Symbol', 'Series', 'Prev Close','Open', 'High', 'Low', 'Last','Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume','%Deliverble') . In this csv file we deal with 3 type of data type(object,float,int ).and it consist 5306 number of rows.

# %%
icici.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.998248  0.997948  0.997853  0.997640
# Open                  0.998248  1.000000  0.999540  0.999457  0.999150
# High                  0.997948  0.999540  1.000000  0.999256  0.999605
# Low                   0.997853  0.999457  0.999256  1.000000  0.999537
# Last                  0.997640  0.999150  0.999605  0.999537  1.000000
# Close                 0.997677  0.999182  0.999627  0.999574  0.999980
# VWAP                  0.997997  0.999524  0.999778  0.999739  0.999840
# Volume               -0.172770 -0.172900 -0.170714 -0.173699 -0.171723
# Turnover              0.100838  0.101385  0.104991  0.099572  0.102937
# Trades               -0.257760 -0.257107 -0.251751 -0.260920 -0.255915
# Deliverable Volume   -0.245802 -0.246138 -0.244808 -0.246331 -0.245188
# %Deliverble          -0.014669 -0.014579 -0.017736 -0.011736 -0.015098
#
# ...

# %%
icici.corr().min()
# Out:
# Prev Close           -0.257760
# Open                 -0.257107
# High                 -0.251751
# Low                  -0.260920
# Last                 -0.255915
# Close                -0.255978
# VWAP                 -0.256320
# Volume               -0.173699
# Turnover             -0.080952
# Trades               -0.267864
# Deliverable Volume   -0.246331
# %Deliverble          -0.267864
# dtype: float64

# %%
i1=icici[icici["Deliverable Volume"]>0]

# %%
i1.head()
# Out:
#            Date     Symbol Series  Prev Close   Open   High    Low   Last  \
# 498  2002-01-01  ICICIBANK     EQ        88.7  89.95  89.95  87.30  88.05
# 499  2002-01-02  ICICIBANK     EQ        88.5  88.00  89.00  87.50  87.60
# 500  2002-01-03  ICICIBANK     EQ        88.4  86.60  92.95  86.60  92.05
# 501  2002-01-04  ICICIBANK     EQ        92.0  92.50  93.20  90.00  91.90
# 502  2002-01-07  ICICIBANK     EQ        91.1  91.00  92.50  89.25  91.05
#
#      Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 498  88.50  88.53   47087  4.168734e+11     NaN             35559.0
# 499  88.40  88.05   70982  6.249913e+11     NaN             64128.0
# 500  92.00  90.40  143055  1.293277e+12     NaN            114325.0
# 501  91.10  91.43   89792  8.209558e+11     NaN             73659.0
# 502  90.15  90.58  151344  1.370891e+12     NaN            123531.0
#
#      %Deliverble
# 498       0.7552
# 499       0.9034
# 500       0.7992
# 501       0.8203
# 502       0.8162

# %%
sns.pairplot(icici)

# %%
i1.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.998001  0.997662  0.997555  0.997316
# Open                  0.998001  1.000000  0.999483  0.999391  0.999046
# High                  0.997662  0.999483  1.000000  0.999165  0.999557
# Low                   0.997555  0.999391  0.999165  1.000000  0.999480
# Last                  0.997316  0.999046  0.999557  0.999480  1.000000
# Close                 0.997358  0.999083  0.999582  0.999521  0.999977
# VWAP                  0.997719  0.999467  0.999752  0.999707  0.999819
# Volume               -0.273355 -0.273411 -0.270900 -0.274600 -0.272237
# Turnover              0.010660  0.011338  0.015430  0.009067  0.012961
# Trades               -0.257760 -0.257107 -0.251751 -0.260920 -0.255915
# Deliverable Volume   -0.245802 -0.246138 -0.244808 -0.246331 -0.245188
# %Deliverble          -0.014669 -0.014579 -0.017736 -0.011736 -0.015098
#
# ...

# %%
icici.corr().min()
# Out:
# Prev Close           -0.257760
# Open                 -0.257107
# High                 -0.251751
# Low                  -0.260920
# Last                 -0.255915
# Close                -0.255978
# VWAP                 -0.256320
# Volume               -0.173699
# Turnover             -0.080952
# Trades               -0.267864
# Deliverable Volume   -0.246331
# %Deliverble          -0.267864
# dtype: float64

# %% [markdown]
# ### In given data of ICICIBANK the Low and volume show max negative reation with the correlation vlue -0.274600. and Last and close value shows positive relationwiyh having correlation 0.999977.

# %% [markdown]
# # 2. Find the patteren accociated with opening ammmount wrt Date Field

# %%
icici.head()
# Out:
#          Date     Symbol Series  Prev Close   Open   High    Low   Last  \
# 0  2000-01-03  ICICIBANK     EQ       69.20  74.35  74.75  71.40  74.75
# 1  2000-01-04  ICICIBANK     EQ       74.75  73.05  78.50  71.00  73.25
# 2  2000-01-05  ICICIBANK     EQ       73.05  70.00  73.50  67.50  70.00
# 3  2000-01-06  ICICIBANK     EQ       69.50  71.00  74.00  69.55  69.75
# 4  2000-01-07  ICICIBANK     EQ       70.05  69.00  72.50  66.00  67.00
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  74.75  73.20  286260  2.095439e+12     NaN                 NaN          NaN
# 1  73.05  73.38  296264  2.173893e+12     NaN                 NaN          NaN
# 2  69.50  70.85  227624  1.612794e+12     NaN                 NaN          NaN
# 3  70.05  72.04  275149  1.982121e+12     NaN                 NaN          NaN
# 4  67.40  68.72  138809  9.538882e+11     NaN                 NaN          NaN

# %%
icici.Date=pd.to_datetime(icici.Date)
icici['year']=icici['Date'].dt.year
icici['month']=icici['Date'].dt.month
icici['day']=icici['Date'].dt.day

# %%
plt.figure(figsize=(20,5))
plt.plot(icici.year,icici.Open)
plt.xticks(range(2000,2022,1));

# %%
a1=icici[icici.year==2014]
a1.head(10)
# Out:
#            Date     Symbol Series  Prev Close     Open     High      Low  \
# 3496 2014-01-01  ICICIBANK     EQ     1098.75  1100.90  1106.05  1092.00
# 3497 2014-01-02  ICICIBANK     EQ     1097.70  1096.15  1118.00  1070.10
# 3498 2014-01-03  ICICIBANK     EQ     1075.60  1068.00  1075.00  1045.00
# 3499 2014-01-06  ICICIBANK     EQ     1066.80  1066.00  1069.00  1035.05
# 3500 2014-01-07  ICICIBANK     EQ     1040.80  1045.05  1059.20  1023.85
#
#          Last   Close     VWAP   Volume      Turnover    Trades  \
# 3496  1101.85  1097.7  1097.71   564158  6.192799e+13   14769.0
# 3497  1074.00  1075.6  1098.21  2058457  2.260608e+14   55849.0
# 3498  1070.05  1066.8  1058.62  2830455  2.996389e+14   70780.0
# 3499  1043.00  1040.8  1045.31  2691321  2.813276e+14   61577.0
# 3500  1050.60  1050.0  1041.69  3375730  3.516453e+14  103736.0
#
#       Deliverable Volume  %Deliverble  year  month  day
# 3496            139240.0       0.2468  2014      1    1
# ...

# %%
a2=icici[icici.year==2020]
a2.head()
# Out:
#            Date     Symbol Series  Prev Close    Open    High     Low    Last  \
# 4974 2020-01-01  ICICIBANK     EQ      538.90  539.90  542.50  535.70  538.00
# 4975 2020-01-02  ICICIBANK     EQ      536.75  536.00  541.90  535.85  540.80
# 4976 2020-01-03  ICICIBANK     EQ      540.60  538.00  540.80  536.25  539.50
# 4977 2020-01-06  ICICIBANK     EQ      538.85  537.25  537.25  523.80  525.70
# 4978 2020-01-07  ICICIBANK     EQ      525.70  531.30  535.60  521.65  524.15
#
#        Close    VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 4974  536.75  538.00   7642793  4.111822e+14   63603.0           3140787.0
# 4975  540.60  539.44  10264223  5.536966e+14   98335.0           5046054.0
# 4976  538.85  538.46   9594690  5.166326e+14   93857.0           4945623.0
# 4977  525.70  527.51  12534334  6.612006e+14  125249.0           7567496.0
# 4978  522.90  526.71  16101835  8.480927e+14  131048.0           8539094.0
#
#       %Deliverble  year  month  day
# ...

# %%
a1.Open.mean()
# Out:
# 1287.489959016393

# %%
a2.Open.mean()
# Out:
# 414.48412698412716

# %%
icici.Open.mean()
# Out:
# 551.558537504711

# %% [markdown]
# ### The opening ammount in 2014 having mean "1287.489959016393" which is approx double with comparision to mean of opening ammount in 2020. But the volume increase with dicrease in opening ammount .

# %% [markdown]
# # 3. Extract the data from jan 2019 to apr 2021 and plot it.

# %%
icici.head(5)
# Out:
#         Date     Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# 0 2000-01-03  ICICIBANK     EQ       69.20  74.35  74.75  71.40  74.75  74.75
# 1 2000-01-04  ICICIBANK     EQ       74.75  73.05  78.50  71.00  73.25  73.05
# 2 2000-01-05  ICICIBANK     EQ       73.05  70.00  73.50  67.50  70.00  69.50
# 3 2000-01-06  ICICIBANK     EQ       69.50  71.00  74.00  69.55  69.75  70.05
# 4 2000-01-07  ICICIBANK     EQ       70.05  69.00  72.50  66.00  67.00  67.40
#
#     VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble  year  \
# 0  73.20  286260  2.095439e+12     NaN                 NaN          NaN  2000
# 1  73.38  296264  2.173893e+12     NaN                 NaN          NaN  2000
# 2  70.85  227624  1.612794e+12     NaN                 NaN          NaN  2000
# 3  72.04  275149  1.982121e+12     NaN                 NaN          NaN  2000
# 4  68.72  138809  9.538882e+11     NaN                 NaN          NaN  2000
#
#    month  day
# ...

# %%
i1=icici[icici.year>2018]

# %%
i1.head()
# Out:
#            Date     Symbol Series  Prev Close    Open   High     Low    Last  \
# 4729 2019-01-01  ICICIBANK     EQ      360.15  361.50  364.8  356.40  364.20
# 4730 2019-01-02  ICICIBANK     EQ      363.75  361.50  367.9  360.30  364.30
# 4731 2019-01-03  ICICIBANK     EQ      364.60  365.00  367.3  362.05  362.10
# 4732 2019-01-04  ICICIBANK     EQ      363.25  361.85  368.8  358.05  366.35
# 4733 2019-01-07  ICICIBANK     EQ      365.20  367.50  371.0  366.55  367.65
#
#        Close    VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 4729  363.75  360.35   7759872  2.796308e+14   65606.0           3670397.0
# 4730  364.60  364.87  18243156  6.656365e+14  133500.0           8786796.0
# 4731  363.25  365.31  12884409  4.706847e+14  114828.0           5954164.0
# 4732  365.20  362.95  22896026  8.310167e+14  173791.0           9611027.0
# 4733  367.70  369.12  12719847  4.695126e+14  123595.0           6130788.0
#
#       %Deliverble  year  month  day
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(i1.Date,i1.Open,'r');
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Openibg ammount" ,fontdict = {"size":20});

# %%
plt.figure(figsize=(20,5))
plt.plot(i1.Date,i1.Volume,'b');
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Volume" ,fontdict = {"size":20});

# %%
plt.figure(figsize=(20,5))
plt.plot(i1.Date,i1.Trades,'g');
plt.xlabel("Date",fontdict = {"size":20});
plt.ylabel("Trades" ,fontdict = {"size":20});
